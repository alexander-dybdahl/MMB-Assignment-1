# %% [markdown]
# # Assignment 1
#
# *Alexander Dybdahl, Alexia Stéphanie Liviana Paratte, Arya Salahshour, Valentin Antoine Roger Vuillon*

# %%
import pandas as pd

df = pd.read_table("lpmc07.dat")
# Out:
#       trip_id  household_id  person_n  trip_n  travel_mode  purpose  fueltype  \
# 0          10             1         0       0            4        3         1
# 1          26             7         0       2            1        3         2
# 2          47            12         0       1            4        5         1
# 3          80            16         0       1            3        5         6
# 4          88            17         4       0            4        3         1
# ...       ...           ...       ...     ...          ...      ...       ...
# 4995    81016         17597         0       4            4        3         1
# 4996    81022         17599         0       0            3        1         6
# 4997    81032         17602         0       0            4        3         1
# 4998    81043         17604         3       1            3        2         1
# 4999    81061         17607         0       3            3        5         6
#
# ...
